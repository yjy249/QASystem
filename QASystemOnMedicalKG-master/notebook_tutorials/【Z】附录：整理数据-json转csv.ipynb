# %% [markdown]
# ## 导入json文件

# %%
import pandas as pd
import json
from tqdm import tqdm
df = pd.DataFrame()
data_path = r'C:\Users\bistu\Downloads\QASystemOnMedicalKG-master\data\medical.json'

# %% [markdown]
# ## json转dataframe

# %%
p_feature = ['category', 'cure_department', 'symptom','check', 'acompany','cure_way','recommand_drug' , 'common_drug', 'drug_detail', 'do_eat','not_eat', 'recommand_eat']

for data in tqdm(open(data_path, encoding='utf8')):
    temp_data = json.loads(data)
    for each in p_feature:
        try:
            temp_data[each] = ','.join(temp_data[each])
        except:
            pass
    
    df = df.append(temp_data, ignore_index=True)
del df['_id']
# Out:
# 0it [00:00, ?it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 4it [00:00, 37.63it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 9it [00:00, 43.02it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 15it [00:00, 46.07it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 21it [00:00, 47.85it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 27it [00:00, 49.20it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 32it [00:00, 45.49it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 37it [00:00, 46.24it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 42it [00:00, 44.88it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 47it [00:01, 45.67it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 52it [00:01, 45.03it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 57it [00:01, 38.26it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 62it [00:01, 38.26it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 66it [00:01, 34.68it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 71it [00:01, 37.07it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 77it [00:01, 41.52it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 83it [00:01, 44.68it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 89it [00:02, 46.59it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 94it [00:02, 44.41it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 99it [00:02, 45.19it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 104it [00:02, 44.30it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 109it [00:02, 43.84it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 114it [00:02, 45.04it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 119it [00:02, 44.53it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 125it [00:02, 45.20it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 130it [00:02, 46.33it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 135it [00:03, 46.61it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 140it [00:03, 42.63it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 145it [00:03, 42.61it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 150it [00:03, 43.35it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 155it [00:03, 40.79it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 160it [00:03, 42.52it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 165it [00:03, 44.21it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 170it [00:03, 42.83it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 175it [00:04, 41.00it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 180it [00:04, 41.67it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 185it [00:04, 40.67it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# ...
#   df = df.append(temp_data, ignore_index=True)
# 8746it [04:01, 35.28it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8750it [04:01, 33.81it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8754it [04:01, 34.78it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8758it [04:01, 34.54it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8762it [04:02, 34.98it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8766it [04:02, 34.52it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8770it [04:02, 34.08it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8774it [04:02, 30.99it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8778it [04:02, 31.82it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8782it [04:02, 32.11it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8786it [04:02, 30.56it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8790it [04:03, 30.49it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8794it [04:03, 30.45it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8798it [04:03, 29.75it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8801it [04:03, 29.53it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8804it [04:03, 26.98it/s]C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# C:\Users\bistu\AppData\Local\Temp\ipykernel_23648\3699493334.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_data, ignore_index=True)
# 8808it [04:03, 36.15it/s]

# %% [markdown]
# ## 调整列名和顺序

# %%
orders = ['name', 'desc', 'category', 'cure_department', 'cause', 'symptom', 'check', 'acompany', 'cost_money',
       'cure_lasttime', 'cure_way', 'cured_prob', 'easy_get',
        'get_prob', 'get_way', 'prevent',
       'recommand_drug' , 'common_drug', 'drug_detail', 'do_eat',
       'not_eat', 'recommand_eat', 'yibao_status']
df = df[orders]
orders_cn = ['疾病名称','疾病描述','疾病种类','科室','病因','症状','检查','并发症','花费','疗程','疗法','治愈率','易感人群','感染概率','感染途径','预防措施','推荐药物','常用药物','具体药物','可以吃','不可以吃','推荐吃','是否纳入医保']
df.columns = orders_cn

# %%
df.head(2)
# Out:
#        疾病名称                                               疾病描述          疾病种类  \
# 0  肺泡蛋白质沉积症  肺泡蛋白质沉积症(简称PAP)，又称Rosen-Castle-man-Liebow综合征，是...  疾病百科,内科,呼吸内科
# 1       百日咳  百日咳(pertussis，whoopingcough)是由百日咳杆菌所致的急性呼吸道传染病...  疾病百科,儿科,小儿内科
#
#         科室                                                 病因  \
# 0  内科,呼吸内科  病因未明，推测与几方面因素有关：如大量粉尘吸入（铝，二氧化硅等），机体免疫功能下降（尤其婴幼...
# 1  儿科,小儿内科  (一)发病原因\n病原菌是鲍特菌属(Bordetella)中的百日咳鲍特菌(B.pertus...
#
#                                   症状  \
# 0                   紫绀,胸痛,呼吸困难,乏力,毓卓
# 1  吸气时有蝉鸣音,痉挛性咳嗽,胸闷,肺阴虚,抽搐,低热,闫鹏辉,惊厥
#
#                                                检查     并发症  \
# 0                               胸部CT检查,肺活检,支气管镜检查  多重肺部感染
# 1  耳、鼻、咽拭子细菌培养,周围血白细胞计数及分类检验,血常规,酶联免疫吸附试验,白细胞分类计数     肺不张
#
#                                        花费     疗程  ...      感染概率   感染途径  \
# 0  根据不同医院，收费标准不一致，省市三甲医院约（ 8000——15000 元）   约3个月  ...  0.00002%   无传染性
# 1       根据不同医院，收费标准不一致，市三甲医院约（1000-4000元）  1-2个月  ...      0.5%  呼吸道传播
#
#                                                 预防措施  \
# 0       1、避免感染分支杆菌病，卡氏肺囊肿肺炎，巨细胞病毒等。\n2、注意锻炼身体，提高免疫力。
# 1  1、控制传染源：在流行季节，若有前驱症状应及早抗生素治疗。\n2、切断传播途径：由于百日咳杆...
#
#                                         推荐药物          常用药物  \
# 0                                                      NaN
# 1  琥乙红霉素片,琥乙红霉素颗粒,百咳静糖浆,穿心莲内酯片,红霉素肠溶片,环酯红霉素片  穿心莲内酯片,百咳静糖浆
#
#                                                 具体药物                可以吃  \
# 0                                                                   NaN
# 1  惠普森穿心莲内酯片(穿心莲内酯片),北京同仁堂百咳静糖浆(百咳静糖浆),邦琪药业百咳静糖浆(...  南瓜子仁,圆白菜,樱桃番茄,小白菜
#
#           不可以吃                                                推荐吃 是否纳入医保
# 0          NaN                                                NaN      否
# 1  螃蟹,海蟹,海虾,海螺  清蒸鸡蛋羹,百合双耳鸡蛋羹,排骨汤,罗汉果雪耳鸡汤,小黄瓜凉拌面,黄瓜三丝汤,黄瓜拌兔丝,黄...      否
#
# [2 rows x 23 columns]

# %%
df.iloc[1]
# Out:
# 疾病名称                                                    百日咳
# 疾病描述      百日咳(pertussis，whoopingcough)是由百日咳杆菌所致的急性呼吸道传染病...
# 疾病种类                                           疾病百科,儿科,小儿内科
# 科室                                                  儿科,小儿内科
# 病因        (一)发病原因\n病原菌是鲍特菌属(Bordetella)中的百日咳鲍特菌(B.pertus...
# 症状                        吸气时有蝉鸣音,痉挛性咳嗽,胸闷,肺阴虚,抽搐,低热,闫鹏辉,惊厥
# 检查           耳、鼻、咽拭子细菌培养,周围血白细胞计数及分类检验,血常规,酶联免疫吸附试验,白细胞分类计数
# 并发症                                                     肺不张
# 花费                        根据不同医院，收费标准不一致，市三甲医院约（1000-4000元）
# 疗程                                                    1-2个月
# 疗法                                               药物治疗,支持性治疗
# 治愈率                                                     98%
# 易感人群                                                  多见于小儿
# 感染概率                                                   0.5%
# 感染途径                                                  呼吸道传播
# 预防措施      1、控制传染源：在流行季节，若有前驱症状应及早抗生素治疗。\n2、切断传播途径：由于百日咳杆...
# 推荐药物              琥乙红霉素片,琥乙红霉素颗粒,百咳静糖浆,穿心莲内酯片,红霉素肠溶片,环酯红霉素片
# 常用药物                                           穿心莲内酯片,百咳静糖浆
# 具体药物      惠普森穿心莲内酯片(穿心莲内酯片),北京同仁堂百咳静糖浆(百咳静糖浆),邦琪药业百咳静糖浆(...
# 可以吃                                       南瓜子仁,圆白菜,樱桃番茄,小白菜
# 不可以吃                                            螃蟹,海蟹,海虾,海螺
# 推荐吃       清蒸鸡蛋羹,百合双耳鸡蛋羹,排骨汤,罗汉果雪耳鸡汤,小黄瓜凉拌面,黄瓜三丝汤,黄瓜拌兔丝,黄...
# 是否纳入医保                                                    否
# Name: 1, dtype: object

# %% [markdown]
# ## 导出csv文件

# %%
df.to_csv('medical_data.csv', index=False)
